# %%
from HeatModel import *

# %%
n = 50
A = HeatModel(n)

# %%
x1, count, tols = A.GaussSeidel(nIter=1000)

# %%
count
# Out:
# 1000

# %%
plt.plot(tols)

# %%
tols[-1]
# Out:
# 0.576239237115941

# %%
sns.heatmap(x1.reshape((n,n)))
# Out:
# <Axes: >
