# %%
# Importing the class
from HeatModel import *

# %%
# Calling the constructor with n = 50 and base parameters
n = 50
A = HeatModel(n)

# %%
# Visualizing the design matrix and the target vector
A.visualizeModelDesign()

# %%
# Generating a solution with GS. Plotting with plot = True
x1gs, countgs, tolsgs = A.GaussSeidel(nIter = 10000, stop = True, plot = True)

# %%
print(f"Gauss Seidel converted in {countgs} iterations.")
# Out:
# Gauss Seidel converted in 1840 iterations.

# %%
# Generating a solution with Jacobi. Plotting with plot = True
x1j, countj, tolsj = A.solveJacobi(nIter = 10000, stop = True, plot = True)

# %%
print(f"Jacobi converged in {countj} iterations")
# Out:
# Jacobi converged in 6298 iterations
